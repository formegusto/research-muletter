# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
from sklearn.metrics.pairwise import euclidean_distances as euc
import json
import numpy as np
import pandas as pd
import datetime as dt
from web import DB, SeedZoneController, CoordGenerator

db = DB()
seed_ctrl = SeedZoneController()
coord_gen = CoordGenerator()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
with open("datas/test_dataset.json", "r") as json_file:
    json_data = json.load(json_file)

# %%
features = pd.DataFrame()

for d in json_data:
    features = features.append(d, ignore_index=True)

features = features.sample(n=len(features))
features.head()
# Out:
#                     trackId  danceability  energy  key  loudness  speechiness  \
# 235  5HFl0JaGH9FPvI4Z7kVINo         0.639   0.510  6.0    -6.921       0.0796
# 107  7kyupZQftQDUUxlATGGmOe         0.768   0.862  8.0    -4.247       0.2370
# 133  6LNj8wNR6xL2bvCng2T91L         0.896   0.606  1.0    -6.169       0.2440
# 83   70AYiGbc4mWZGEqiipBBDb         0.638   0.490  4.0    -5.726       0.2260
# 41   0Q5VnK2DYzRyfqQRJuUtvi         0.703   0.709  1.0    -4.169       0.0433
#
#      acousticness  instrumentalness  liveness  valence    tempo
# 235       0.79100          0.000002    0.0902    0.654   88.898
# 107       0.20000          0.000000    0.3380    0.839  134.003
# 133       0.31700          0.000000    0.1080    0.713   90.012
# 83        0.88500          0.011600    0.1560    0.403  179.905
# 41        0.00379          0.000054    0.3330    0.538  117.941

# %%
seed_ctrl.make_new_cluster()
# Out:
# 1 round : ECV 28.75%
# 2 round : ECV 52.27%
# 3 round : ECV 54.64%
# 4 round : ECV 55.67%
# 5 round : ECV 56.27%
# 6 round : ECV 56.52%
# 7 round : ECV 57.0%
# 8 round : ECV 57.1%
# 9 round : ECV 57.15%
# 10 round : ECV 57.22%
# 11 round : ECV 57.47%
# 12 round : ECV 57.75%
# 13 round : ECV 58.04%
# 14 round : ECV 58.2%
# 15 round : ECV 58.3%
# 16 round : ECV 58.32%
# 17 round : ECV 58.37%
# 18 round : ECV 58.43%
# 19 round : ECV 58.47%
# 20 round : ECV 58.47%
# 21 round : ECV 58.47%
# 22 round : ECV 58.47%
# 23 round : ECV 58.47%
# 24 round : ECV 58.47%
# 25 round : ECV 58.47%
# [56.79561583 56.30071982 58.6248175  58.37343004 58.55018697 58.89085814
#  59.20964965 57.09381056 57.24998727 59.26989729 57.17968598 57.52238422
#  59.6176554  58.40172491 58.37825079 58.16513733 57.76001145 58.14220536
#  58.94549479 56.91444366 58.46789281]
# Clustering End. ECV 59.61765539991968 data Select
# [ 4.  6.  3.  5. 10.  0.  1.  8.  7.  9.  2.]
# sorting okay

# %%
seed_ctrl.seed_features.head()
# Out:
#                   trackId  danceability  energy  key  loudness  speechiness  \
# 0  3TSLqZssCoCdDlMhCJ08XW         0.680   0.584    8    -4.457       0.0340
# 1  2oBMZYteeO8DyXV9gDx6Za         0.412   0.940    1    -2.171       0.2150
# 2  0IGUXY4JbK18bu9oD4mPIm         0.755   0.870    1    -2.414       0.0936
# 3  5quFr5s5PXYfUX5jV2EBZ1         0.492   0.615    2    -6.663       0.2440
# 4  3gFcGnU4kTdMYLXDjH1TK8         0.722   0.676   11    -5.885       0.0829
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0      0.443000          0.000000    0.0628    0.239  118.060
# 1      0.064800          0.000000    0.3580    0.423  157.964
# 2      0.009880          0.000000    0.0917    0.645  124.032
# 3      0.196000          0.000000    0.0772    0.458   90.081
# 4      0.000835          0.000012    0.3210    0.362  129.943

# %%
seed_ctrl.norm_features.head()
# Out:
#                   trackId  danceability    energy       key  loudness  \
# 0  3TSLqZssCoCdDlMhCJ08XW      0.525368  0.562201  0.727273  0.769885
# 1  2oBMZYteeO8DyXV9gDx6Za      0.086743  0.988038  0.090909  0.893747
# 2  0IGUXY4JbK18bu9oD4mPIm      0.648118  0.904306  0.090909  0.880581
# 3  5quFr5s5PXYfUX5jV2EBZ1      0.217676  0.599282  0.181818  0.650358
# 4  3gFcGnU4kTdMYLXDjH1TK8      0.594108  0.672249  1.000000  0.692512
#
#    speechiness  acousticness  instrumentalness  liveness   valence     tempo
# 0     0.018082      0.458416           0.00000  0.040754  0.184481  0.384522
# 1     0.398654      0.066776           0.00000  0.416709  0.392603  0.671636
# 2     0.143398      0.009905           0.00000  0.077560  0.643705  0.427491
# 3     0.459630      0.202639           0.00000  0.059093  0.432191  0.183209
# 4     0.120900      0.000538           0.00002  0.369587  0.323606  0.470022

# %%
seed_ctrl.music_label.head()
# Out:
#                   trackId  label
# 0  3TSLqZssCoCdDlMhCJ08XW      0
# 1  2oBMZYteeO8DyXV9gDx6Za      7
# 2  0IGUXY4JbK18bu9oD4mPIm      9
# 3  5quFr5s5PXYfUX5jV2EBZ1      8
# 4  3gFcGnU4kTdMYLXDjH1TK8      1

# %%
coord_gen.all_remake_coords()
