# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
from sklearn.metrics.pairwise import euclidean_distances as euc
import json
import numpy as np
import pandas as pd
import datetime as dt
from web import DB, SeedZoneController

db = DB()
seed_ctrl = SeedZoneController()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
with open("datas/test_dataset.json", "r") as json_file:
    json_data = json.load(json_file)

# %%
features = pd.DataFrame()

for d in json_data:
    features = features.append(d, ignore_index=True)

features = features.sample(n=len(features))
features.head()
# Out:
#                     trackId  danceability  energy  key  loudness  speechiness  \
# 194  6mrHRESWNiMu6UJviv8KpP         0.654   0.704  6.0    -5.826       0.0362
# 209  0IqHoofEMMDF8PNGa4cBXZ         0.571   0.283  8.0    -7.308       0.0283
# 122  75wMWF4RDY8HiqR0EKGefH         0.657   0.736  0.0    -5.543       0.0894
# 108  4EaxY2suYRqcgjhPKgM16P         0.759   0.784  9.0    -3.675       0.1500
# 132  5wSY3C2sp9sAy0y5qLh9gi         0.707   0.607  7.0    -4.559       0.0254
#
#      acousticness  instrumentalness  liveness  valence    tempo
# 194        0.8320           0.15800    0.0911    0.465   95.048
# 209        0.9180           0.00002    0.1140    0.202  108.890
# 122        0.0349           0.00000    0.0843    0.482   92.029
# 108        0.0161           0.00585    0.2660    0.914   95.081
# 132        0.1900           0.00000    0.0758    0.309   89.957

# %%
seed_ctrl.make_new_cluster()
# Out:
# 1 round : ECV 33.1%
# 2 round : ECV 52.87%
# 3 round : ECV 55.73%
# 4 round : ECV 56.84%
# 5 round : ECV 57.35%
# 6 round : ECV 57.93%
# 7 round : ECV 58.05%
# 8 round : ECV 58.06%
# 9 round : ECV 58.06%
# 10 round : ECV 58.06%
# 11 round : ECV 58.06%
# 12 round : ECV 58.06%
# 13 round : ECV 58.06%
# 14 round : ECV 58.06%
# [57.25034633 58.30564842 58.97439867 58.91725895 58.42961117 58.32459963
#  59.12872825 59.02419346 57.88240863 58.6670241  57.08426608 58.79634218
#  58.34780164 59.72829856 58.36890888 58.40466216 58.21596871 57.74634772
#  58.28334511 58.42893217 58.06218127]
# Clustering End. ECV 59.728298564468886 data Select
# [ 2.  7.  3.  0.  8.  6.  9.  1. 10.  5.  4.]
# sorting okay

# %%
seed_ctrl.seed_features.head()
# Out:
#                   trackId  danceability  energy  key  loudness  speechiness  \
# 0  6SwETSlZoH20S9ScCNzufA         0.694   0.559  1.0    -6.930       0.0608
# 1  7GkHIsnziYgk6j1lx2TK6H         0.528   0.423  8.0    -7.381       0.0264
# 2  63irPUP3xB74fHdw1Aw9zR         0.581   0.800  1.0    -2.613       0.4110
# 3  6LNj8wNR6xL2bvCng2T91L         0.896   0.606  1.0    -6.169       0.2440
# 4  1Al4Z4K76RCKj31mExavs7         0.522   0.922  5.0    -4.805       0.0616
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0      0.247000           0.00000    0.1690    0.304  118.012
# 1      0.678000           0.00148    0.1670    0.249  135.917
# 2      0.154000           0.00000    0.0697    0.709  119.872
# 3      0.317000           0.00000    0.1080    0.713   90.012
# 4      0.000745           0.00000    0.0976    0.530  176.105

# %%
seed_ctrl.norm_features.head()
# Out:
#                   trackId  danceability    energy       key  loudness  \
# 0  6SwETSlZoH20S9ScCNzufA      0.545305  0.532297  0.090909  0.635891
# 1  7GkHIsnziYgk6j1lx2TK6H      0.271829  0.369617  0.727273  0.611454
# 2  63irPUP3xB74fHdw1Aw9zR      0.359143  0.820574  0.090909  0.869798
# 3  6LNj8wNR6xL2bvCng2T91L      0.878089  0.588517  0.090909  0.677124
# 4  1Al4Z4K76RCKj31mExavs7      0.261944  0.966507  0.454545  0.751029
#
#    speechiness  acousticness  instrumentalness  liveness   valence     tempo
# 0     0.074432      0.255451          0.000000  0.176006  0.258002  0.384176
# 1     0.002103      0.701766          0.002521  0.173459  0.195792  0.513005
# 2     0.810765      0.159146          0.000000  0.049542  0.716095  0.397559
# 3     0.459630      0.327938          0.000000  0.098319  0.720620  0.182713
# 4     0.076114      0.000445          0.000000  0.085074  0.513630  0.802163

# %%
seed_ctrl.music_label.head()
# Out:
#                   trackId  label
# 0  6SwETSlZoH20S9ScCNzufA      0
# 1  7GkHIsnziYgk6j1lx2TK6H      3
# 2  63irPUP3xB74fHdw1Aw9zR      7
# 3  6LNj8wNR6xL2bvCng2T91L     10
# 4  1Al4Z4K76RCKj31mExavs7      1
